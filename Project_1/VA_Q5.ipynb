# %%
import pandas as pd
import seaborn as sns
import datetime
import warnings
from matplotlib import pyplot as plt
import numpy as np
from plotly.subplots import make_subplots

warnings.filterwarnings("ignore")

# %%
data = pd.read_excel("PreprocessingVaccine.xlsx")

# %%
data.head()
# Out:
#    Unnamed: 0    Country      Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0           0  Argentina  12/29/20   Oxford/AstraZeneca                   1
# 1           1  Argentina  12/29/20    Sinopharm/Beijing                   1
# 2           2  Argentina  12/29/20            Sputnik V               20488
# 3           3  Argentina  12/30/20            Sputnik V               40590
# 4           4  Argentina  12/31/20            Sputnik V               43396
#
#    Severe_disease_Beta_var_Gamma_var_Delta_var  \
# 0                                            0
# 1                                            0
# 2                                        18234
# 3                                        36125
# 4                                        38622
#
#    Infection_Beta_var_Gamma_var_Delta_var  Infection_Omicron_var  \
# 0                                       0                      0
# 1                                       0                      0
# 2                                   17414                   7375
# 3                                   34501                  14612
# 4                                   36886                  15622
#
#    SevereDisease_Ancestral_var_Alpha_var  Infection_Ancestral_var_Alpha_var  \
# 0                                      0                                  0
# 1                                      0                                  0
# 2                                  18848                              17619
# 3                                  37342                              34907
# 4                                  39924                              37320
#
#    Severe_disease_Omicron_var
# 0                           0
# 1                           0
# 2                       11268
# 3                       22324
# 4                       23867

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Date', 'Vaccine_Manufacturer',
#        'Total_Vaccinations', 'Severe_disease_Beta_var_Gamma_var_Delta_var',
#        'Infection_Beta_var_Gamma_var_Delta_var', 'Infection_Omicron_var',
#        'SevereDisease_Ancestral_var_Alpha_var',
#        'Infection_Ancestral_var_Alpha_var', 'Severe_disease_Omicron_var'],
#       dtype='object')

# %%
data = data.drop(columns = "Unnamed: 0", axis = 1)

# %%
data = data.drop(columns = ["Severe_disease_Beta_var_Gamma_var_Delta_var", "Infection_Beta_var_Gamma_var_Delta_var","Infection_Omicron_var", "SevereDisease_Ancestral_var_Alpha_var", "Infection_Ancestral_var_Alpha_var", "Severe_disease_Omicron_var"], axis = 1)

# %%
data
# Out:
#          Country      Date Vaccine_Manufacturer  Total_Vaccinations
# 0      Argentina  12/29/20   Oxford/AstraZeneca                   1
# 1      Argentina  12/29/20    Sinopharm/Beijing                   1
# 2      Argentina  12/29/20            Sputnik V               20488
# 3      Argentina  12/30/20            Sputnik V               40590
# 4      Argentina  12/31/20            Sputnik V               43396
# ...          ...       ...                  ...                 ...
# 41545    Uruguay  10/12/22      Pfizer/BioNTech             2556144
# 41546    Uruguay  10/13/22      Pfizer/BioNTech             2556166
# 41547    Uruguay  10/14/22      Pfizer/BioNTech             2556194
# 41548    Uruguay  10/15/22      Pfizer/BioNTech             2556197
# 41549    Uruguay  10/17/22      Pfizer/BioNTech             2556226
#
# [41550 rows x 4 columns]

# %%
data_1 = pd.read_excel("Vaccine_efficacy.xlsx", sheet_name=2)
data_1
# Out:
#      Vaccine_Manufacturer Protection from Severe Disease  \
# 0                     NaN                      Ancestral
# 1                 CanSino                             66
# 2                 Covaxin                             78
# 3         Johnson&Johnson                             86
# 4             Medicago***                             89
# ...                   ...                            ...
# 3206                  NaN                            NaN
# 3207                  NaN                            NaN
# 3208                  NaN                            NaN
# 3209                  NaN                            NaN
# 3210                  NaN                            NaN
#
#      Protection from Infection Protection from Severe Disease.1  \
# 0                    Ancestral                            Alpha
# 1                           62                               66
# 2                           73                               78
# 3                           72                               86
# 4                           75                               89
# ...                        ...                              ...
# 3206                       NaN                              NaN
# 3207                       NaN                              NaN
# 3208                       NaN                              NaN
# 3209                       NaN                              NaN
# 3210                       NaN                              NaN
#
#      Protection from Infection.1 Protection from Severe Disease.2  \
# 0                          Alpha                             Beta
# 1                             62                               64
# 2                             73                               76
# 3                             72                               76
# 4                             75                               89
# ...                          ...                              ...
# 3206                         NaN                              NaN
# 3207                         NaN                              NaN
# 3208                         NaN                              NaN
# 3209                         NaN                              NaN
# 3210                           0                              NaN
#
#      Protection from Infection.2 Protection from Severe Disease.3  \
# 0                           Beta                            Gamma
# 1                             61                               64
# 2                             72                               76
# 3                             64                               76
# 4                             75                               89
# ...                          ...                              ...
# 3206                         NaN                              NaN
# 3207                         NaN                              NaN
# 3208                         NaN                              NaN
# 3209                         NaN                              NaN
# 3210                         NaN                              NaN
#
#      Protection from Infection.3 Protection from Severe Disease.4  \
# 0                          Gamma                            delta
# 1                             61                               64
# 2                             72                               76
# 3                             64                               76
# 4                             75                               89
# ...                          ...                              ...
# 3206                         NaN                              NaN
# 3207                         NaN                              NaN
# 3208                         NaN                              NaN
# 3209                         NaN                              NaN
# 3210                         NaN                              NaN
#
#      Protection from Infection.4 Protection from Severe Disease.5  \
# 0                          Delta                          Omicron
# 1                             61                               48
# 2                             72                               57
# 3                             64                               57
# 4                             75                               65
# ...                          ...                              ...
# 3206                         NaN                              NaN
# 3207                         NaN                              NaN
# 3208                         NaN                              NaN
# 3209                         NaN                              NaN
# 3210                         NaN                              NaN
#
#      Protection from Infection.5
# 0                        Omicron
# 1                             32
# 2                             38
# 3                             33
# 4                             43
# ...                          ...
# 3206                         NaN
# 3207                         NaN
# 3208                         NaN
# 3209                         NaN
# 3210                         NaN
#
# [3211 rows x 13 columns]

# %%
data_1 = data_1.drop(columns = ["Protection from Severe Disease.1", "Protection from Infection.1"], axis = 1)

# %%
data_1 = data_1.drop(columns = ["Protection from Severe Disease.3", "Protection from Infection.3", "Protection from Severe Disease.4", "Protection from Infection.4"], axis = 1)

# %%
data_1 = data_1.rename(columns={'Protection from Severe Disease': 'Protection_from_Severe_Disease_Alpha_Ancestral', 'Protection from Infection': 'Protection_from_Infection_Alpha_Ancestral'})

# %%
data_1 = data_1.rename(columns={'Protection from Severe Disease.2': 'Protection_from_Severe_Disease_Beta_Gamma_Delta', 'Protection from Infection.2': 'Protection_from_Infection_Beta_Gamma_Delta'})

# %%
# data_1 = data_1.rename(columns={'Protection_from Severe_Disease_Beta_Gamma_Delta': 'Protection_from_Severe_Disease_Beta_Gamma_Delta'})

# %%
data_1 = data_1.rename(columns={'Protection from Severe Disease.5': 'Protection_from_Severe_Disease_Omicron', 'Protection from Infection.5': 'Protection_from_Infection_Omicron'})

# %%
data_1.isnull().sum()
# Out:
# Vaccine_Manufacturer                               3196
# Protection_from_Severe_Disease_Alpha_Ancestral     3197
# Protection_from_Infection_Alpha_Ancestral          3197
# Protection_from_Severe_Disease_Beta_Gamma_Delta    3197
# Protection_from_Infection_Beta_Gamma_Delta         3197
# Protection_from_Severe_Disease_Omicron             3197
# Protection_from_Infection_Omicron                  3197
# dtype: int64

# %%
data_1["Vaccine_Manufacturer"].unique()
# Out:
# array([nan, 'CanSino', 'Covaxin', 'Johnson&Johnson', 'Medicago***',
#        'Moderna', 'Novavax', 'Oxford/AstraZeneca', 'Pfizer/BioNTech',
#        'Sinopharm/Beijing', 'Sinovac/Coronavac', 'SKYCovione',
#        'Sputnik V', 'Valneva**',
#        '** Exact effciacy data not readily available. Data for other vaccine category was used for this analysis.',
#        '*** For Medicago no Omicron data is available. For completion purposes, we used Novavx data since the severe disease protection is similar to Novavax vaccine.'],
#       dtype=object)

# %%
data_1 = data_1.dropna()

# %%
data_1["Vaccine_Manufacturer"].unique()
# Out:
# array(['CanSino', 'Covaxin', 'Johnson&Johnson', 'Medicago***', 'Moderna',
#        'Novavax', 'Oxford/AstraZeneca', 'Pfizer/BioNTech',
#        'Sinopharm/Beijing', 'Sinovac/Coronavac', 'SKYCovione',
#        'Sputnik V', 'Valneva**'], dtype=object)

# %%
data["Vaccine_Manufacturer"].unique()
# Out:
# array(['Oxford/AstraZeneca', 'Sinopharm/Beijing', 'Sputnik V',
#        'Pfizer/BioNTech', 'CanSino', 'Moderna', 'Johnson&Johnson',
#        'Novavax', 'Valneva', 'Medicago', 'Sinovac', 'Covaxin',
#        'SKYCovione'], dtype=object)

# %%
data_1['Vaccine_Manufacturer'] = data_1['Vaccine_Manufacturer'].replace(['Medicago***'], 'Medicago')

# %%
data_1['Vaccine_Manufacturer'] = data_1['Vaccine_Manufacturer'].replace(['Valneva**'], 'Valneva')

# %%
data_1['Vaccine_Manufacturer'] = data_1['Vaccine_Manufacturer'].replace(['Sinovac/Coronavac'], 'Sinovac')

# %%
data_1["Vaccine_Manufacturer"].unique()
# Out:
# array(['CanSino', 'Covaxin', 'Johnson&Johnson', 'Medicago', 'Moderna',
#        'Novavax', 'Oxford/AstraZeneca', 'Pfizer/BioNTech',
#        'Sinopharm/Beijing', 'Sinovac', 'SKYCovione', 'Sputnik V',
#        'Valneva'], dtype=object)

# %%
# merged_data = pd.merge(data, data_1, on = 'Vaccine_Manufacturer', how='inner')

# %%
# merged_data["Vaccine_Manufacturer"].unique()

# %%
# merged_data

# %%
# data['year'] = pd.DatetimeIndex(data['Date']).year
data['Date'] = pd.to_datetime(data['Date'])

# %%
# merged_data

# %%
data
# Out:
#          Country       Date Vaccine_Manufacturer  Total_Vaccinations
# 0      Argentina 2020-12-29   Oxford/AstraZeneca                   1
# 1      Argentina 2020-12-29    Sinopharm/Beijing                   1
# 2      Argentina 2020-12-29            Sputnik V               20488
# 3      Argentina 2020-12-30            Sputnik V               40590
# 4      Argentina 2020-12-31            Sputnik V               43396
# ...          ...        ...                  ...                 ...
# 41545    Uruguay 2022-10-12      Pfizer/BioNTech             2556144
# 41546    Uruguay 2022-10-13      Pfizer/BioNTech             2556166
# 41547    Uruguay 2022-10-14      Pfizer/BioNTech             2556194
# 41548    Uruguay 2022-10-15      Pfizer/BioNTech             2556197
# 41549    Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
# [41550 rows x 4 columns]

# %%
data.reset_index(drop=True, inplace=True)

# %%
order_total = data.groupby(['Country', 'Vaccine_Manufacturer'])["Total_Vaccinations"].transform(max) == data["Total_Vaccinations"]
df_1 = data[order_total]

# %%
df_1
# Out:
#              Country       Date Vaccine_Manufacturer  Total_Vaccinations
# 3188       Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 3196       Argentina 2022-10-14            Sputnik V            20742641
# 3197       Argentina 2022-10-15              CanSino              979735
# 3201       Argentina 2022-10-16              Moderna            13252207
# 3202       Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ...              ...        ...                  ...                 ...
# 40362  United States 2022-10-12              Moderna           235757021
# 40363  United States 2022-10-12      Pfizer/BioNTech           372455530
# 41524        Uruguay 2022-09-16              Sinovac             3248161
# 41544        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 41549        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
# [363 rows x 4 columns]

# %%
df_1.drop_duplicates(subset=['Country','Vaccine_Manufacturer'], inplace=True)

# %%
df_1 = df_1[df_1['Total_Vaccinations'] > 1]

# %%
df_1
# Out:
#              Country       Date Vaccine_Manufacturer  Total_Vaccinations
# 3188       Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 3196       Argentina 2022-10-14            Sputnik V            20742641
# 3197       Argentina 2022-10-15              CanSino              979735
# 3201       Argentina 2022-10-16              Moderna            13252207
# 3202       Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ...              ...        ...                  ...                 ...
# 40362  United States 2022-10-12              Moderna           235757021
# 40363  United States 2022-10-12      Pfizer/BioNTech           372455530
# 41524        Uruguay 2022-09-16              Sinovac             3248161
# 41544        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 41549        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
# [200 rows x 4 columns]

# %%
df_1.shape
# Out:
# (200, 4)

# %%
df_1.reset_index(drop=True, inplace=True)

# %%
df_1.columns
# Out:
# Index(['Country', 'Date', 'Vaccine_Manufacturer', 'Total_Vaccinations'], dtype='object')

# %%
df_1
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
# [200 rows x 4 columns]

# %%
df_1['CountrywiseTotalVaccination'] = df_1.groupby(['Country'])['Total_Vaccinations'].transform('sum')

# %%
# pd.DataFrame(df_1.groupby(['Country'])['Total_Vaccinations'].transform('sum'))

# %%
df_1
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination
# 0                      109748183
# 1                      109748183
# 2                      109748183
# 3                      109748183
# 4                      109748183
# ..                           ...
# 195                    627128998
# 196                    627128998
# 197                      5895528
# 198                      5895528
# 199                      5895528
#
# [200 rows x 5 columns]

# %%
# order_total_1 = data.groupby('Country')["Total_Vaccinations"].sum().rename("Country_Total_Vaccinations").reset_index()
# df_1 = data.merge(order_total_1)

# %%
# df_1["Percentage_of_Vaccination"] = df_1["Total_Vaccinations"] / df_1["CountrywiseTotalVaccination"]

# %%
df_1["Percentage_of_Vaccination_2"]  = df_1['Total_Vaccinations'] / df_1["CountrywiseTotalVaccination"]

# %%
df_1
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
# [200 rows x 6 columns]

# %%
df_1['Total_Percentage_of_Vaccination_2'] = (df_1.groupby(['Country'])['Percentage_of_Vaccination_2'].transform('sum'))*100

# %%
# df_1.to_csv('df_1.csv', encoding='utf-8', index=False)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            200 non-null    object
#  1   Date                               200 non-null    datetime64[ns]
#  2   Vaccine_Manufacturer               200 non-null    object
#  3   Total_Vaccinations                 200 non-null    int64
#  4   CountrywiseTotalVaccination        200 non-null    int64
#  5   Percentage_of_Vaccination_2        200 non-null    float64
#  6   Total_Percentage_of_Vaccination_2  200 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 11.1+ KB

# %%
df_1
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
# [200 rows x 7 columns]

# %%
data_1
# Out:
#    Vaccine_Manufacturer Protection_from_Severe_Disease_Alpha_Ancestral  \
# 1               CanSino                                             66
# 2               Covaxin                                             78
# 3       Johnson&Johnson                                             86
# 4              Medicago                                             89
# 5               Moderna                                             97
# 6               Novavax                                             89
# 7    Oxford/AstraZeneca                                             94
# 8       Pfizer/BioNTech                                             95
# 9     Sinopharm/Beijing                                             73
# 10              Sinovac                                             50
# 11           SKYCovione                                             75
# 12            Sputnik V                                             92
# 13              Valneva                                             75
#
#    Protection_from_Infection_Alpha_Ancestral  \
# 1                                         62
# 2                                         73
# 3                                         72
# 4                                         75
# 5                                         92
# 6                                         83
# 7                                         63
# 8                                         86
# 9                                         68
# 10                                        47
# 11                                        70
# 12                                        86
# 13                                        70
#
#    Protection_from_Severe_Disease_Beta_Gamma_Delta  \
# 1                                               64
# 2                                               76
# 3                                               76
# 4                                               89
# 5                                               97
# 6                                               86
# 7                                               94
# 8                                               95
# 9                                               71
# 10                                              49
# 11                                              73
# 12                                              89
# 13                                              73
#
#    Protection_from_Infection_Beta_Gamma_Delta  \
# 1                                          61
# 2                                          72
# 3                                          64
# 4                                          75
# 5                                          91
# 6                                          82
# 7                                          69
# 8                                          84
# 9                                          67
# 10                                         46
# 11                                         69
# 12                                         85
# 13                                         69
#
#    Protection_from_Severe_Disease_Omicron Protection_from_Infection_Omicron
# 1                                      48                                32
# 2                                      57                                38
# 3                                      57                                33
# 4                                      65                                43
# 5                                      73                                48
# 6                                      65                                43
# 7                                      71                                36
# 8                                      72                                44
# 9                                      53                                35
# 10                                     37                                24
# 11                                     55                                36
# 12                                     67                                44
# 13                                     55                                36

# %%
merged_data = pd.merge(df_1,data_1,on = 'Vaccine_Manufacturer', how='left')

# %%
merged_data
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2  \
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
#     Protection_from_Severe_Disease_Alpha_Ancestral  \
# 0                                               94
# 1                                               92
# 2                                               66
# 3                                               97
# 4                                               95
# ..                                             ...
# 195                                             97
# 196                                             95
# 197                                             50
# 198                                             94
# 199                                             95
#
#     Protection_from_Infection_Alpha_Ancestral  \
# 0                                          63
# 1                                          86
# 2                                          62
# 3                                          92
# 4                                          86
# ..                                        ...
# 195                                        92
# 196                                        86
# 197                                        47
# 198                                        63
# 199                                        86
#
#     Protection_from_Severe_Disease_Beta_Gamma_Delta  \
# 0                                                94
# 1                                                89
# 2                                                64
# 3                                                97
# 4                                                95
# ..                                              ...
# 195                                              97
# 196                                              95
# 197                                              49
# 198                                              94
# 199                                              95
#
#     Protection_from_Infection_Beta_Gamma_Delta  \
# 0                                           69
# 1                                           85
# 2                                           61
# 3                                           91
# 4                                           84
# ..                                         ...
# 195                                         91
# 196                                         84
# 197                                         46
# 198                                         69
# 199                                         84
#
#     Protection_from_Severe_Disease_Omicron Protection_from_Infection_Omicron
# 0                                       71                                36
# 1                                       67                                44
# 2                                       48                                32
# 3                                       73                                48
# 4                                       72                                44
# ..                                     ...                               ...
# 195                                     73                                48
# 196                                     72                                44
# 197                                     37                                24
# 198                                     71                                36
# 199                                     72                                44
#
# [200 rows x 13 columns]

# %%
merged_data['Omicron_Severe_Disease_Efficacy'] = merged_data['Protection_from_Severe_Disease_Omicron'] * merged_data['Percentage_of_Vaccination_2']

# %%
merged_data
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2  \
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
#     Protection_from_Severe_Disease_Alpha_Ancestral  \
# 0                                               94
# 1                                               92
# 2                                               66
# 3                                               97
# 4                                               95
# ..                                             ...
# 195                                             97
# 196                                             95
# 197                                             50
# 198                                             94
# 199                                             95
#
#     Protection_from_Infection_Alpha_Ancestral  \
# 0                                          63
# 1                                          86
# 2                                          62
# 3                                          92
# 4                                          86
# ..                                        ...
# 195                                        92
# 196                                        86
# 197                                        47
# 198                                        63
# 199                                        86
#
#     Protection_from_Severe_Disease_Beta_Gamma_Delta  \
# 0                                                94
# 1                                                89
# 2                                                64
# 3                                                97
# 4                                                95
# ..                                              ...
# 195                                              97
# 196                                              95
# 197                                              49
# 198                                              94
# 199                                              95
#
#     Protection_from_Infection_Beta_Gamma_Delta  \
# 0                                           69
# 1                                           85
# 2                                           61
# 3                                           91
# 4                                           84
# ..                                         ...
# 195                                         91
# 196                                         84
# 197                                         46
# 198                                         69
# 199                                         84
#
#     Protection_from_Severe_Disease_Omicron Protection_from_Infection_Omicron  \
# 0                                       71                                36
# 1                                       67                                44
# 2                                       48                                32
# 3                                       73                                48
# 4                                       72                                44
# ..                                     ...                               ...
# 195                                     73                                48
# 196                                     72                                44
# 197                                     37                                24
# 198                                     71                                36
# 199                                     72                                44
#
#     Omicron_Severe_Disease_Efficacy
# 0                          17.31149
# 1                         12.663143
# 2                          0.428502
# 3                          8.814826
# 4                         12.554262
# ..                              ...
# 195                       27.442939
# 196                       42.761215
# 197                       20.385275
# 198                        1.097613
# 199                       31.218285
#
# [200 rows x 14 columns]

# %%
merged_data['Omicron_Infection_Efficacy'] = merged_data['Protection_from_Infection_Omicron'] * merged_data['Percentage_of_Vaccination_2']

# %%
merged_data['Alpha_Ancestral_Severe_Disease_Efficacy'] = merged_data['Protection_from_Severe_Disease_Alpha_Ancestral'] * merged_data['Percentage_of_Vaccination_2']

# %%
merged_data['Alpha_Ancestral_Infection_Efficacy'] = merged_data['Protection_from_Infection_Alpha_Ancestral'] * merged_data['Percentage_of_Vaccination_2']

# %%
merged_data['Beta_Gamma_Delta_Severe_Disease_Efficacy'] = merged_data['Protection_from_Severe_Disease_Beta_Gamma_Delta'] * merged_data['Percentage_of_Vaccination_2']

# %%
merged_data['Beta_Gamma_Delta_Infection_Efficacy'] = merged_data['Protection_from_Infection_Beta_Gamma_Delta'] * merged_data['Percentage_of_Vaccination_2']

# %%
merged_data
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2  \
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
#     Protection_from_Severe_Disease_Alpha_Ancestral  \
# 0                                               94
# 1                                               92
# 2                                               66
# 3                                               97
# 4                                               95
# ..                                             ...
# 195                                             97
# 196                                             95
# 197                                             50
# 198                                             94
# 199                                             95
#
#     Protection_from_Infection_Alpha_Ancestral  \
# 0                                          63
# 1                                          86
# 2                                          62
# 3                                          92
# 4                                          86
# ..                                        ...
# 195                                        92
# 196                                        86
# 197                                        47
# 198                                        63
# 199                                        86
#
#     Protection_from_Severe_Disease_Beta_Gamma_Delta  \
# 0                                                94
# 1                                                89
# 2                                                64
# 3                                                97
# 4                                                95
# ..                                              ...
# 195                                              97
# 196                                              95
# 197                                              49
# 198                                              94
# 199                                              95
#
#     Protection_from_Infection_Beta_Gamma_Delta  \
# 0                                           69
# 1                                           85
# 2                                           61
# 3                                           91
# 4                                           84
# ..                                         ...
# 195                                         91
# 196                                         84
# 197                                         46
# 198                                         69
# 199                                         84
#
#     Protection_from_Severe_Disease_Omicron Protection_from_Infection_Omicron  \
# 0                                       71                                36
# 1                                       67                                44
# 2                                       48                                32
# 3                                       73                                48
# 4                                       72                                44
# ..                                     ...                               ...
# 195                                     73                                48
# 196                                     72                                44
# 197                                     37                                24
# 198                                     71                                36
# 199                                     72                                44
#
#     Omicron_Severe_Disease_Efficacy Omicron_Infection_Efficacy  \
# 0                          17.31149                   8.777657
# 1                         12.663143                   8.316094
# 2                          0.428502                   0.285668
# 3                          8.814826                    5.79605
# 4                         12.554262                   7.672049
# ..                              ...                        ...
# 195                       27.442939                  18.044672
# 196                       42.761215                  26.131854
# 197                       20.385275                  13.222881
# 198                        1.097613                   0.556536
# 199                       31.218285                  19.077841
#
#     Alpha_Ancestral_Severe_Disease_Efficacy  \
# 0                                 22.919438
# 1                                 17.388197
# 2                                   0.58919
# 3                                 11.712851
# 4                                 16.564651
# ..                                      ...
# 195                               36.465274
# 196                               56.421048
# 197                               27.547668
# 198                                1.453178
# 199                               41.190792
#
#     Alpha_Ancestral_Infection_Efficacy  \
# 0                              15.3609
# 1                            16.254184
# 2                             0.553481
# 3                            11.109095
# 4                            14.995368
# ..                                 ...
# 195                          34.585621
# 196                          51.075896
# 197                          25.894808
# 198                           0.973939
# 199                          37.288507
#
#     Beta_Gamma_Delta_Severe_Disease_Efficacy  \
# 0                                  22.919438
# 1                                   16.82119
# 2                                   0.571336
# 3                                  11.712851
# 4                                  16.564651
# ..                                       ...
# 195                                36.465274
# 196                                56.421048
# 197                                26.996715
# 198                                 1.453178
# 199                                41.190792
#
#     Beta_Gamma_Delta_Infection_Efficacy
# 0                             16.823843
# 1                             16.065182
# 2                              0.544554
# 3                             10.988344
# 4                             14.646639
# ..                                  ...
# 195                            34.20969
# 196                           49.888085
# 197                           25.343855
# 198                            1.066695
# 199                           36.421332
#
# [200 rows x 19 columns]

# %%
merged_data['Total_Omicron_Severe_Disease_Efficacy'] = merged_data.groupby(['Country'])['Omicron_Severe_Disease_Efficacy'].transform('sum')

# %%
merged_data

# %%
merged_data['Total_Omicron_Infection_Efficacy'] = merged_data.groupby(['Country'])['Omicron_Infection_Efficacy'].transform('sum')

# %%
merged_data
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2  \
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
#     Protection_from_Severe_Disease_Alpha_Ancestral  \
# 0                                               94
# 1                                               92
# 2                                               66
# 3                                               97
# 4                                               95
# ..                                             ...
# 195                                             97
# 196                                             95
# 197                                             50
# 198                                             94
# 199                                             95
#
#     Protection_from_Infection_Alpha_Ancestral  \
# 0                                          63
# 1                                          86
# 2                                          62
# 3                                          92
# 4                                          86
# ..                                        ...
# 195                                        92
# 196                                        86
# 197                                        47
# 198                                        63
# 199                                        86
#
#     Protection_from_Severe_Disease_Beta_Gamma_Delta  ...  \
# 0                                                94  ...
# 1                                                89  ...
# 2                                                64  ...
# 3                                                97  ...
# 4                                                95  ...
# ..                                              ...  ...
# 195                                              97  ...
# 196                                              95  ...
# 197                                              49  ...
# 198                                              94  ...
# 199                                              95  ...
#
#     Protection_from_Severe_Disease_Omicron Protection_from_Infection_Omicron  \
# 0                                       71                                36
# 1                                       67                                44
# 2                                       48                                32
# 3                                       73                                48
# 4                                       72                                44
# ..                                     ...                               ...
# 195                                     73                                48
# 196                                     72                                44
# 197                                     37                                24
# 198                                     71                                36
# 199                                     72                                44
#
#     Omicron_Severe_Disease_Efficacy Omicron_Infection_Efficacy  \
# 0                          17.31149                   8.777657
# 1                         12.663143                   8.316094
# 2                          0.428502                   0.285668
# 3                          8.814826                    5.79605
# 4                         12.554262                   7.672049
# ..                              ...                        ...
# 195                       27.442939                  18.044672
# 196                       42.761215                  26.131854
# 197                       20.385275                  13.222881
# 198                        1.097613                   0.556536
# 199                       31.218285                  19.077841
#
#     Alpha_Ancestral_Severe_Disease_Efficacy  \
# 0                                 22.919438
# 1                                 17.388197
# 2                                   0.58919
# 3                                 11.712851
# 4                                 16.564651
# ..                                      ...
# 195                               36.465274
# 196                               56.421048
# 197                               27.547668
# 198                                1.453178
# 199                               41.190792
#
#     Alpha_Ancestral_Infection_Efficacy  \
# 0                              15.3609
# 1                            16.254184
# 2                             0.553481
# 3                            11.109095
# 4                            14.995368
# ..                                 ...
# 195                          34.585621
# 196                          51.075896
# 197                          25.894808
# 198                           0.973939
# 199                          37.288507
#
#     Beta_Gamma_Delta_Severe_Disease_Efficacy  \
# 0                                  22.919438
# 1                                   16.82119
# 2                                   0.571336
# 3                                  11.712851
# 4                                  16.564651
# ..                                       ...
# 195                                36.465274
# 196                                56.421048
# 197                                26.996715
# 198                                 1.453178
# 199                                41.190792
#
#     Beta_Gamma_Delta_Infection_Efficacy Total_Omicron_Severe_Disease_Efficacy  \
# 0                             16.823843                             65.718174
# 1                             16.065182                             65.718174
# 2                              0.544554                             65.718174
# 3                             10.988344                             65.718174
# 4                             14.646639                             65.718174
# ..                                  ...                                   ...
# 195                            34.20969                             71.923477
# 196                           49.888085                             71.923477
# 197                           25.343855                             52.701173
# 198                            1.066695                             52.701173
# 199                           36.421332                             52.701173
#
#     Total_Omicron_Infection_Efficacy
# 0                          40.057108
# 1                          40.057108
# 2                          40.057108
# 3                          40.057108
# 4                          40.057108
# ..                               ...
# 195                        45.171923
# 196                        45.171923
# 197                        32.857258
# 198                        32.857258
# 199                        32.857258
#
# [200 rows x 21 columns]

# %%
merged_data['Total_Alpha_Ancestral_Severe_Disease_Efficacy'] = merged_data.groupby(['Country'])['Alpha_Ancestral_Severe_Disease_Efficacy'].transform('sum')

# %%
merged_data['Total_Alpha_Ancestral_Infection_Efficacy'] = merged_data.groupby(['Country'])['Alpha_Ancestral_Infection_Efficacy'].transform('sum')

# %%
merged_data['Total_Beta_Gamma_Delta_Severe_Disease_Efficacy'] = merged_data.groupby(['Country'])['Beta_Gamma_Delta_Severe_Disease_Efficacy'].transform('sum')

# %%
merged_data['Total_Beta_Gamma_Delta_Infection_Efficacy'] = merged_data.groupby(['Country'])['Beta_Gamma_Delta_Infection_Efficacy'].transform('sum')

# %%
merged_data
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2  \
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
#     Protection_from_Severe_Disease_Alpha_Ancestral  \
# 0                                               94
# 1                                               92
# 2                                               66
# 3                                               97
# 4                                               95
# ..                                             ...
# 195                                             97
# 196                                             95
# 197                                             50
# 198                                             94
# 199                                             95
#
#     Protection_from_Infection_Alpha_Ancestral  \
# 0                                          63
# 1                                          86
# 2                                          62
# 3                                          92
# 4                                          86
# ..                                        ...
# 195                                        92
# 196                                        86
# 197                                        47
# 198                                        63
# 199                                        86
#
#     Protection_from_Severe_Disease_Beta_Gamma_Delta  ...  \
# 0                                                94  ...
# 1                                                89  ...
# 2                                                64  ...
# 3                                                97  ...
# 4                                                95  ...
# ..                                              ...  ...
# 195                                              97  ...
# 196                                              95  ...
# 197                                              49  ...
# 198                                              94  ...
# 199                                              95  ...
#
#     Alpha_Ancestral_Severe_Disease_Efficacy  \
# 0                                 22.919438
# 1                                 17.388197
# 2                                   0.58919
# 3                                 11.712851
# 4                                 16.564651
# ..                                      ...
# 195                               36.465274
# 196                               56.421048
# 197                               27.547668
# 198                                1.453178
# 199                               41.190792
#
#     Alpha_Ancestral_Infection_Efficacy  \
# 0                              15.3609
# 1                            16.254184
# 2                             0.553481
# 3                            11.109095
# 4                            14.995368
# ..                                 ...
# 195                          34.585621
# 196                          51.075896
# 197                          25.894808
# 198                           0.973939
# 199                          37.288507
#
#     Beta_Gamma_Delta_Severe_Disease_Efficacy  \
# 0                                  22.919438
# 1                                   16.82119
# 2                                   0.571336
# 3                                  11.712851
# 4                                  16.564651
# ..                                       ...
# 195                                36.465274
# 196                                56.421048
# 197                                26.996715
# 198                                 1.453178
# 199                                41.190792
#
#     Beta_Gamma_Delta_Infection_Efficacy Total_Omicron_Severe_Disease_Efficacy  \
# 0                             16.823843                             65.718174
# 1                             16.065182                             65.718174
# 2                              0.544554                             65.718174
# 3                             10.988344                             65.718174
# 4                             14.646639                             65.718174
# ..                                  ...                                   ...
# 195                            34.20969                             71.923477
# 196                           49.888085                             71.923477
# 197                           25.343855                             52.701173
# 198                            1.066695                             52.701173
# 199                           36.421332                             52.701173
#
#     Total_Omicron_Infection_Efficacy  \
# 0                          40.057108
# 1                          40.057108
# 2                          40.057108
# 3                          40.057108
# 4                          40.057108
# ..                               ...
# 195                        45.171923
# 196                        45.171923
# 197                        32.857258
# 198                        32.857258
# 199                        32.857258
#
#     Total_Alpha_Ancestral_Severe_Disease_Efficacy  \
# 0                                         88.3829
# 1                                         88.3829
# 2                                         88.3829
# 3                                         88.3829
# 4                                         88.3829
# ..                                            ...
# 195                                     95.480389
# 196                                     95.480389
# 197                                     70.191639
# 198                                     70.191639
# 199                                     70.191639
#
#     Total_Alpha_Ancestral_Infection_Efficacy  \
# 0                                  76.165947
# 1                                  76.165947
# 2                                  76.165947
# 3                                  76.165947
# 4                                  76.165947
# ..                                       ...
# 195                                87.833294
# 196                                87.833294
# 197                                64.157254
# 198                                64.157254
# 199                                64.157254
#
#     Total_Beta_Gamma_Delta_Severe_Disease_Efficacy  \
# 0                                        87.271777
# 1                                        87.271777
# 2                                        87.271777
# 3                                        87.271777
# 4                                        87.271777
# ..                                             ...
# 195                                      95.178754
# 196                                      95.178754
# 197                                      69.640686
# 198                                      69.640686
# 199                                      69.640686
#
#     Total_Beta_Gamma_Delta_Infection_Efficacy
# 0                                   76.698349
# 1                                   76.698349
# 2                                   76.698349
# 3                                   76.698349
# 4                                   76.698349
# ..                                        ...
# 195                                 86.028243
# 196                                 86.028243
# 197                                 62.831882
# 198                                 62.831882
# 199                                 62.831882
#
# [200 rows x 25 columns]

# %%
# merged_data.to_csv('merged_data.csv', encoding='utf-8', index=False)

# %%
# df_1['new_column_2'] = df_1.groupby(['Country', "Vaccine_Manufacturer"])['Percentage_of_Vaccination_2'].transform('sum')

# %%
merged_data

# %%
merged_data['Susceptible_BreakOut_for_Omicron_Severe_Disease'] = merged_data['Total_Percentage_of_Vaccination_2'] - merged_data['Total_Omicron_Severe_Disease_Efficacy']

# %%
merged_data
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2  \
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
#     Protection_from_Severe_Disease_Alpha_Ancestral  \
# 0                                               94
# 1                                               92
# 2                                               66
# 3                                               97
# 4                                               95
# ..                                             ...
# 195                                             97
# 196                                             95
# 197                                             50
# 198                                             94
# 199                                             95
#
#     Protection_from_Infection_Alpha_Ancestral  \
# 0                                          63
# 1                                          86
# 2                                          62
# 3                                          92
# 4                                          86
# ..                                        ...
# 195                                        92
# 196                                        86
# 197                                        47
# 198                                        63
# 199                                        86
#
#     Protection_from_Severe_Disease_Beta_Gamma_Delta  ...  \
# 0                                                94  ...
# 1                                                89  ...
# 2                                                64  ...
# 3                                                97  ...
# 4                                                95  ...
# ..                                              ...  ...
# 195                                              97  ...
# 196                                              95  ...
# 197                                              49  ...
# 198                                              94  ...
# 199                                              95  ...
#
#     Alpha_Ancestral_Infection_Efficacy  \
# 0                              15.3609
# 1                            16.254184
# 2                             0.553481
# 3                            11.109095
# 4                            14.995368
# ..                                 ...
# 195                          34.585621
# 196                          51.075896
# 197                          25.894808
# 198                           0.973939
# 199                          37.288507
#
#     Beta_Gamma_Delta_Severe_Disease_Efficacy  \
# 0                                  22.919438
# 1                                   16.82119
# 2                                   0.571336
# 3                                  11.712851
# 4                                  16.564651
# ..                                       ...
# 195                                36.465274
# 196                                56.421048
# 197                                26.996715
# 198                                 1.453178
# 199                                41.190792
#
#     Beta_Gamma_Delta_Infection_Efficacy Total_Omicron_Severe_Disease_Efficacy  \
# 0                             16.823843                             65.718174
# 1                             16.065182                             65.718174
# 2                              0.544554                             65.718174
# 3                             10.988344                             65.718174
# 4                             14.646639                             65.718174
# ..                                  ...                                   ...
# 195                            34.20969                             71.923477
# 196                           49.888085                             71.923477
# 197                           25.343855                             52.701173
# 198                            1.066695                             52.701173
# 199                           36.421332                             52.701173
#
#     Total_Omicron_Infection_Efficacy  \
# 0                          40.057108
# 1                          40.057108
# 2                          40.057108
# 3                          40.057108
# 4                          40.057108
# ..                               ...
# 195                        45.171923
# 196                        45.171923
# 197                        32.857258
# 198                        32.857258
# 199                        32.857258
#
#     Total_Alpha_Ancestral_Severe_Disease_Efficacy  \
# 0                                         88.3829
# 1                                         88.3829
# 2                                         88.3829
# 3                                         88.3829
# 4                                         88.3829
# ..                                            ...
# 195                                     95.480389
# 196                                     95.480389
# 197                                     70.191639
# 198                                     70.191639
# 199                                     70.191639
#
#     Total_Alpha_Ancestral_Infection_Efficacy  \
# 0                                  76.165947
# 1                                  76.165947
# 2                                  76.165947
# 3                                  76.165947
# 4                                  76.165947
# ..                                       ...
# 195                                87.833294
# 196                                87.833294
# 197                                64.157254
# 198                                64.157254
# 199                                64.157254
#
#     Total_Beta_Gamma_Delta_Severe_Disease_Efficacy  \
# 0                                        87.271777
# 1                                        87.271777
# 2                                        87.271777
# 3                                        87.271777
# 4                                        87.271777
# ..                                             ...
# 195                                      95.178754
# 196                                      95.178754
# 197                                      69.640686
# 198                                      69.640686
# 199                                      69.640686
#
#     Total_Beta_Gamma_Delta_Infection_Efficacy  \
# 0                                   76.698349
# 1                                   76.698349
# 2                                   76.698349
# 3                                   76.698349
# 4                                   76.698349
# ..                                        ...
# 195                                 86.028243
# 196                                 86.028243
# 197                                 62.831882
# 198                                 62.831882
# 199                                 62.831882
#
#     Susceptible_BreakOut_for_Omicron_Severe_Disease
# 0                                         34.281826
# 1                                         34.281826
# 2                                         34.281826
# 3                                         34.281826
# 4                                         34.281826
# ..                                              ...
# 195                                       28.076523
# 196                                       28.076523
# 197                                       47.298827
# 198                                       47.298827
# 199                                       47.298827
#
# [200 rows x 26 columns]

# %%
merged_data['Susceptible_BreakOut_for_Omicron_Infection'] = merged_data['Total_Percentage_of_Vaccination_2'] - merged_data['Total_Omicron_Infection_Efficacy']

# %%
merged_data['Susceptible_BreakOut_for_Alpha_Ancestral_Severe_Disease'] = merged_data['Total_Percentage_of_Vaccination_2'] - merged_data['Total_Alpha_Ancestral_Severe_Disease_Efficacy']

# %%
merged_data['Susceptible_BreakOut_for_Alpha_Ancestral_Infection'] = merged_data['Total_Percentage_of_Vaccination_2'] - merged_data['Total_Alpha_Ancestral_Infection_Efficacy']

# %%
merged_data['Susceptible_BreakOut_for_Beta_Gamma_Delta_Severe_Disease'] = merged_data['Total_Percentage_of_Vaccination_2'] - merged_data['Total_Beta_Gamma_Delta_Severe_Disease_Efficacy']

# %%
merged_data['Susceptible_BreakOut_for_Beta_Gamma_Delta_Infection'] = merged_data['Total_Percentage_of_Vaccination_2'] - merged_data['Total_Beta_Gamma_Delta_Infection_Efficacy']

# %%
merged_data
# Out:
#            Country       Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0        Argentina 2022-10-13   Oxford/AstraZeneca            26759220
# 1        Argentina 2022-10-14            Sputnik V            20742641
# 2        Argentina 2022-10-15              CanSino              979735
# 3        Argentina 2022-10-16              Moderna            13252207
# 4        Argentina 2022-10-16      Pfizer/BioNTech            19136214
# ..             ...        ...                  ...                 ...
# 195  United States 2022-10-12              Moderna           235757021
# 196  United States 2022-10-12      Pfizer/BioNTech           372455530
# 197        Uruguay 2022-09-16              Sinovac             3248161
# 198        Uruguay 2022-10-12   Oxford/AstraZeneca               91141
# 199        Uruguay 2022-10-17      Pfizer/BioNTech             2556226
#
#      CountrywiseTotalVaccination  Percentage_of_Vaccination_2  \
# 0                      109748183                     0.243824
# 1                      109748183                     0.189002
# 2                      109748183                     0.008927
# 3                      109748183                     0.120751
# 4                      109748183                     0.174365
# ..                           ...                          ...
# 195                    627128998                     0.375931
# 196                    627128998                     0.593906
# 197                      5895528                     0.550953
# 198                      5895528                     0.015459
# 199                      5895528                     0.433587
#
#      Total_Percentage_of_Vaccination_2  \
# 0                                100.0
# 1                                100.0
# 2                                100.0
# 3                                100.0
# 4                                100.0
# ..                                 ...
# 195                              100.0
# 196                              100.0
# 197                              100.0
# 198                              100.0
# 199                              100.0
#
#     Protection_from_Severe_Disease_Alpha_Ancestral  \
# 0                                               94
# 1                                               92
# 2                                               66
# 3                                               97
# 4                                               95
# ..                                             ...
# 195                                             97
# 196                                             95
# 197                                             50
# 198                                             94
# 199                                             95
#
#     Protection_from_Infection_Alpha_Ancestral  \
# 0                                          63
# 1                                          86
# 2                                          62
# 3                                          92
# 4                                          86
# ..                                        ...
# 195                                        92
# 196                                        86
# 197                                        47
# 198                                        63
# 199                                        86
#
#     Protection_from_Severe_Disease_Beta_Gamma_Delta  ...  \
# 0                                                94  ...
# 1                                                89  ...
# 2                                                64  ...
# 3                                                97  ...
# 4                                                95  ...
# ..                                              ...  ...
# 195                                              97  ...
# 196                                              95  ...
# 197                                              49  ...
# 198                                              94  ...
# 199                                              95  ...
#
#     Total_Alpha_Ancestral_Severe_Disease_Efficacy  \
# 0                                         88.3829
# 1                                         88.3829
# 2                                         88.3829
# 3                                         88.3829
# 4                                         88.3829
# ..                                            ...
# 195                                     95.480389
# 196                                     95.480389
# 197                                     70.191639
# 198                                     70.191639
# 199                                     70.191639
#
#     Total_Alpha_Ancestral_Infection_Efficacy  \
# 0                                  76.165947
# 1                                  76.165947
# 2                                  76.165947
# 3                                  76.165947
# 4                                  76.165947
# ..                                       ...
# 195                                87.833294
# 196                                87.833294
# 197                                64.157254
# 198                                64.157254
# 199                                64.157254
#
#     Total_Beta_Gamma_Delta_Severe_Disease_Efficacy  \
# 0                                        87.271777
# 1                                        87.271777
# 2                                        87.271777
# 3                                        87.271777
# 4                                        87.271777
# ..                                             ...
# 195                                      95.178754
# 196                                      95.178754
# 197                                      69.640686
# 198                                      69.640686
# 199                                      69.640686
#
#     Total_Beta_Gamma_Delta_Infection_Efficacy  \
# 0                                   76.698349
# 1                                   76.698349
# 2                                   76.698349
# 3                                   76.698349
# 4                                   76.698349
# ..                                        ...
# 195                                 86.028243
# 196                                 86.028243
# 197                                 62.831882
# 198                                 62.831882
# 199                                 62.831882
#
#     Susceptible_BreakOut_for_Omicron_Severe_Disease  \
# 0                                         34.281826
# 1                                         34.281826
# 2                                         34.281826
# 3                                         34.281826
# 4                                         34.281826
# ..                                              ...
# 195                                       28.076523
# 196                                       28.076523
# 197                                       47.298827
# 198                                       47.298827
# 199                                       47.298827
#
#     Susceptible_BreakOut_for_Omicron_Infection  \
# 0                                    59.942892
# 1                                    59.942892
# 2                                    59.942892
# 3                                    59.942892
# 4                                    59.942892
# ..                                         ...
# 195                                  54.828077
# 196                                  54.828077
# 197                                  67.142742
# 198                                  67.142742
# 199                                  67.142742
#
#     Susceptible_BreakOut_for_Alpha_Ancestral_Severe_Disease  \
# 0                                              11.6171
# 1                                              11.6171
# 2                                              11.6171
# 3                                              11.6171
# 4                                              11.6171
# ..                                                 ...
# 195                                           4.519611
# 196                                           4.519611
# 197                                          29.808361
# 198                                          29.808361
# 199                                          29.808361
#
#     Susceptible_BreakOut_for_Alpha_Ancestral_Infection  \
# 0                                            23.834053
# 1                                            23.834053
# 2                                            23.834053
# 3                                            23.834053
# 4                                            23.834053
# ..                                                 ...
# 195                                          12.166706
# 196                                          12.166706
# 197                                          35.842746
# 198                                          35.842746
# 199                                          35.842746
#
#     Susceptible_BreakOut_for_Beta_Gamma_Delta_Severe_Disease  \
# 0                                            12.728223
# 1                                            12.728223
# 2                                            12.728223
# 3                                            12.728223
# 4                                            12.728223
# ..                                                 ...
# 195                                           4.821246
# 196                                           4.821246
# 197                                          30.359314
# 198                                          30.359314
# 199                                          30.359314
#
#     Susceptible_BreakOut_for_Beta_Gamma_Delta_Infection
# 0                                            23.301651
# 1                                            23.301651
# 2                                            23.301651
# 3                                            23.301651
# 4                                            23.301651
# ..                                                 ...
# 195                                          13.971757
# 196                                          13.971757
# 197                                          37.168118
# 198                                          37.168118
# 199                                          37.168118
#
# [200 rows x 31 columns]

# %%
merged_data.to_csv('VaccineBreakout_1.csv', encoding='utf-8', index=False)

# %%
merged_data['year'] = pd.DatetimeIndex(merged_data['Date']).year

# %%
merged_data

# %%
cy_group = merged_data.groupby(["Country", "year"])

# %%
cy_group.first()

# %%
merged_data['Country'].unique()

# %%
df = merged_data.query("Country=='Argentina'")

# %%
df

# %%
# import plotly.express as px
# df = merged_data.query("Country=='Argentina'")
# fig = plt.figure(figsize=[40,30])
# fig = px.line(df, y= ["Susceptible_BreakOut_for_Omicorn_Infection",""], x= "Date", color = "Country",title='Susceptible BreakOut for Omicorn Infection in Argentina', markers=True)
# fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure()

# %%
import plotly.graph_objects as go

# Add data
# month = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
#          'August', 'September', 'October', 'November', 'December']
# high_2000 = [32.5, 37.6, 49.9, 53.0, 69.1, 75.4, 76.5, 76.6, 70.7, 60.6, 45.1, 29.3]
# low_2000 = [13.8, 22.3, 32.5, 37.2, 49.9, 56.1, 57.7, 58.3, 51.2, 42.8, 31.6, 15.9]
# high_2007 = [36.5, 26.6, 43.6, 52.3, 71.5, 81.4, 80.5, 82.2, 76.0, 67.3, 46.1, 35.0]
# low_2007 = [23.6, 14.0, 27.0, 36.8, 47.6, 57.7, 58.9, 61.2, 53.3, 48.5, 31.0, 23.6]
# high_2014 = [28.8, 28.5, 37.0, 56.8, 69.7, 79.7, 78.5, 77.8, 74.1, 62.6, 45.3, 39.9]
# low_2014 = [12.7, 14.3, 18.6, 35.5, 49.9, 58.0, 60.0, 58.6, 51.7, 45.2, 32.2, 29.1]

df = merged_data.query("Country=='Argentina'")


fig = go.Figure()
# Create and style traces
fig.add_trace(go.Scatter(x=df['Country'], y=df['Susceptible_BreakOut_for_Omicorn_Infection'], name='Susceptible BreakOut for Omicorn Infection',
                         line=dict(color='firebrick', width=4)))

fig.add_trace(go.Scatter(x=df['Country'], y=df['Susceptible_BreakOut_for_Omicorn_Severe_Disease'], name = 'Susceptible BreakOut for Omicorn Severe Disease',
                         line=dict(color='royalblue', width=4)))

fig.add_trace(go.Scatter(x=df['Country'], y=df['Susceptible_BreakOut_for_Alpha_Ancestral_Severe_Disease'], name='Susceptible BreakOut for Alpha Ancestral Severe Disease',
                         line=dict(color='firebrick', width=4,
                              dash='dash') # dash options include 'dash', 'dot', and 'dashdot'
))
fig.add_trace(go.Scatter(x=df['Country'], y=df['Susceptible_BreakOut_for_Alpha_Ancestral_Infection'], name='Susceptible BreakOut for Alpha Ancestral Infection',
                         line = dict(color='royalblue', width=4, dash='dash')))

fig.add_trace(go.Scatter(x=df['Country'], y=df['Susceptible_BreakOut_for_Beta_Gamma_Delta_Severe_Disease'], name='Susceptible BreakOut for Beta Gamma Delta Severe Disease',
                         line = dict(color='firebrick', width=4, dash='dot')))

fig.add_trace(go.Scatter(x=df['Country'], y=df['Susceptible_BreakOut_for_Beta_Gamma_Delta_Infection'], name='Susceptible BreakOut for Beta Gamma Delta Infection',
                         line=dict(color='royalblue', width=4, dash='dot')))

# Edit the layout
fig.update_layout(title='Susceptible BreakOut in Argentina',
                   xaxis_title='Country',
                   yaxis_title='Breakout')


fig.show()

# %%
fig = px.bar(df, y=['Susceptible_BreakOut_for_Omicorn_Severe_Disease', 'Susceptible_BreakOut_for_Omicorn_Infection'], x='CountrywiseTotalVaccination')
fig.show()

# %%
import plotly.graph_objects as go

colors = ['lightslategray',] * 5
colors[1] = 'crimson'

fig = go.Figure()

fig.add_trace(go.Bar(x = df['Country'],y=df['Susceptible_BreakOut_for_Omicorn_Infection'], name='Susceptible BreakOut for Omicorn Infection'))

fig.add_trace(go.Bar(x = df['Country'],y=df['Susceptible_BreakOut_for_Omicorn_Severe_Disease'], name='Susceptible BreakOut for Omicorn Severe Disease'))


fig.add_trace(go.Bar(x = df['Country'],y=df['Susceptible_BreakOut_for_Alpha_Ancestral_Severe_Disease'], name='Susceptible BreakOut for Alpha Ancestral Severe Disease'))

fig.add_trace(go.Bar(x = df['Country'],y=df['Susceptible_BreakOut_for_Alpha_Ancestral_Infection'], name='Susceptible BreakOut for Alpha Ancestral Infection'))

fig.add_trace(go.Bar(x = df['Country'],y=df['Susceptible_BreakOut_for_Beta_Gamma_Delta_Severe_Disease'], name='Susceptible BreakOut for Beta Gamma Delta Severe Disease'))

fig.add_trace(go.Bar(x = df['Country'],y=df['Susceptible_BreakOut_for_Beta_Gamma_Delta_Infection'], name='Susceptible BreakOut for Beta Gamma Delta Infection'))


fig.update_layout(title_text='Susceptible BreakOut in Argentina')

# %%
df

# %%
y = df[['Susceptible_BreakOut_for_Omicorn_Infection', 'Susceptible_BreakOut_for_Omicorn_Severe_Disease']]
y

# %%
import plotly.graph_objects as go

y = df[['Susceptible_BreakOut_for_Omicorn_Infection', 'Susceptible_BreakOut_for_Omicorn_Severe_Disease']]

x = df[['Country']]

# Use the hovertext kw argument for hover text
fig = go.Figure(data=[go.Bar(x=x, y=y)])
# Customize aspect
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5, opacity=0.6)
fig.update_layout(title_text='Susceptible BreakOut in Argentina')
fig.show()

# %%
test = df_1.groupby(["Country", "Vaccine_Manufacturer"])

# %%
test.first()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_1.info()

# %%
# g = df.groupby('Vaccine_Manufacturer')['Total_Vaccinations'].value_counts().reset_index(name='t')
# g['size'] = df.groupby('c')['type'].transform('size')

# %%
df_1.groupby(['Country'])['Total_Vaccinations'].transform(lambda x: x/x.sum())

# %%
df_1

# %%
df_1.groupby(['Country', 'Vaccine_Manufacturer'])['Total_Vaccinations'].sum().rename("Courses").groupby(level = 0).transform(lambda x: x/x.sum())

# %%
df_3 = df_1[total]
